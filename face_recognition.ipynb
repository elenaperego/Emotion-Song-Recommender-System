# %%
from deepface import DeepFace
# Out:
# 2023-03-09 19:44:37.645124: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
face_analysis = DeepFace.analyze(img_path = "/Users/mischatomaszrauch/UM/AcademicYear_03/04_Period/IntelligentSystems/emotion-song-recommender/database/Mischa.jpg")
print(face_analysis)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  7.08it/s]
# [{'emotion': {'angry': 5.058629955030782e-16, 'disgust': 1.3592825033951627e-28, 'fear': 2.2512698819590643e-17, 'happy': 99.99958872792654, 'sad': 3.6078986726967884e-15, 'surprise': 1.6338946771474983e-13, 'neutral': 0.0004126845642947006}, 'dominant_emotion': 'happy', 'region': {'x': 1953, 'y': 746, 'w': 1170, 'h': 1170}, 'age': 24, 'gender': {'Woman': 0.13234749203547835, 'Man': 99.86764788627625}, 'dominant_gender': 'Man', 'race': {'asian': 0.04358116420917213, 'indian': 0.16676425002515316, 'black': 0.006122087506810203, 'white': 84.05798673629761, 'middle eastern': 7.28401318192482, 'latino hispanic': 8.441534638404846}, 'dominant_race': 'white'}]

# %%
data = DeepFace.stream('database')
print(data)
#Read more at: https://viso.ai/computer-vision/deepface/
# Out:
# facial recognition model VGG-Face is just built
# Age model is just built
# Gender model is just built
# Emotion model is just built
# WARNING: Representations for images in database folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  1  representations found in  representations_vgg_face.pkl
# find function lasts  0.4453709125518799  seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = DeepFace.stream('database')
#       2 print(data)
#       3 #Read more at: https://viso.ai/computer-vision/deepface/
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/deepface/DeepFace.py:736, in stream(db_path, model_name, detector_backend, distance_metric, enable_face_analysis, source, time_threshold, frame_threshold)
#     730 if frame_threshold < 1:
#     731     raise ValueError(
#     732         "frame_threshold must be greater than the value 1 but you passed "
#     733         + str(frame_threshold)
#     734     )
# --> 736 realtime.analysis(
#     737     db_path,
#     738     model_name,
#     739     detector_backend,
#     740     distance_metric,
#     741     enable_face_analysis,
#     742     source=source,
#     743     time_threshold=time_threshold,
#     744     frame_threshold=frame_threshold,
#     745 )
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/deepface/commons/realtime.py:176, in analysis(db_path, model_name, detector_backend, distance_metric, enable_face_analysis, source, time_threshold, frame_threshold)
#     171 # -------------------------------
#     172 # facial attribute analysis
#     174 if enable_face_analysis == True:
# --> 176     demographies = DeepFace.analyze(
#     177         img_path=custom_face,
#     178         detector_backend=detector_backend,
#     179         enforce_detection=False,
#     180         silent=True,
#     181     )
#     183     if len(demographies) > 0:
#     184         # directly access 1st face cos img is extracted already
#     185         demography = demographies[0]
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/deepface/DeepFace.py:364, in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     361     obj["dominant_gender"] = Gender.labels[np.argmax(gender_predictions)]
#     363 elif action == "race":
# --> 364     race_predictions = models["race"].predict(img_content, verbose=0)[0, :]
#     365     sum_of_predictions = race_predictions.sum()
#     367     obj["race"] = {}
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/keras/engine/training.py:2317, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2308     except ValueError:
#    2309         warnings.warn(
#    2310             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2311             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2314             stacklevel=2,
#    2315         )
# -> 2317 data_handler = data_adapter.get_data_handler(
#    2318     x=x,
#    2319     batch_size=batch_size,
#    2320     steps_per_epoch=steps,
#    2321     initial_epoch=0,
#    2322     epochs=1,
#    2323     max_queue_size=max_queue_size,
#    2324     workers=workers,
#    2325     use_multiprocessing=use_multiprocessing,
#    2326     model=self,
#    2327     steps_per_execution=self._steps_per_execution,
#    2328 )
#    2330 # Container that configures and calls `tf.keras.Callback`s.
#    2331 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/keras/engine/data_adapter.py:1579, in get_data_handler(*args, **kwargs)
#    1577 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1578     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1579 return DataHandler(*args, **kwargs)
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/keras/engine/data_adapter.py:1259, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1256     self._steps_per_execution = steps_per_execution
#    1258 adapter_cls = select_data_adapter(x, y)
# -> 1259 self._adapter = adapter_cls(
#    1260     x,
#    1261     y,
#    1262     batch_size=batch_size,
#    1263     steps=steps_per_epoch,
#    1264     epochs=epochs - initial_epoch,
#    1265     sample_weights=sample_weight,
#    1266     shuffle=shuffle,
#    1267     max_queue_size=max_queue_size,
#    1268     workers=workers,
#    1269     use_multiprocessing=use_multiprocessing,
#    1270     distribution_strategy=tf.distribute.get_strategy(),
#    1271     model=model,
#    1272 )
#    1274 strategy = tf.distribute.get_strategy()
#    1276 self._current_step = 0
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/keras/engine/data_adapter.py:345, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     342         flat_dataset = flat_dataset.shuffle(1024).repeat(epochs)
#     343     return flat_dataset
# --> 345 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     347 dataset = self.slice_inputs(indices_dataset, inputs)
#     349 if shuffle == "batch":
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:2337, in DatasetV2.flat_map(self, map_func, name)
#    2304 def flat_map(self, map_func, name=None):
#    2305   """Maps `map_func` across this dataset and flattens the result.
#    2306
#    2307   The type signature is:
#    (...)
#    2335     A new `Dataset` with the transformation applied as described above.
#    2336   """
# -> 2337   return FlatMapDataset(self, map_func, name=name)
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:5583, in FlatMapDataset.__init__(self, input_dataset, map_func, name)
#    5581 """See `Dataset.flat_map()` for details."""
#    5582 self._input_dataset = input_dataset
# -> 5583 self._map_func = structured_function.StructuredFunctionWrapper(
#    5584     map_func, self._transformation_name(), dataset=input_dataset)
#    5585 if not isinstance(self._map_func.output_structure, DatasetSpec):
#    5586   raise TypeError(
#    5587       "The `map_func` argument must return a `Dataset` object. Got "
#    5588       f"{_get_type(self._map_func.output_structure)!r}.")
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/data/ops/structured_function.py:263, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     256       warnings.warn(
#     257           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     258           "option is set, this option does not apply to tf.data functions. "
#     259           "To force eager execution of tf.data functions, please use "
#     260           "`tf.data.experimental.enable_debug_mode()`.")
#     261     fn_factory = trace_tf_function(defun_kwargs)
# --> 263 self._function = fn_factory()
#     264 # There is no graph to add in eager mode.
#     265 add_to_graph &= not context.executing_eagerly()
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:226, in TracingCompiler.get_concrete_function(self, *args, **kwargs)
#     217 def get_concrete_function(self, *args, **kwargs):
#     218   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#     219
#     220   Args:
#    (...)
#     224       `tf.Tensor` or `tf.TensorSpec`.
#     225   """
# --> 226   concrete_function = self._get_concrete_function_garbage_collected(
#     227       *args, **kwargs)
#     228   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#     229   return concrete_function
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:192, in TracingCompiler._get_concrete_function_garbage_collected(self, *args, **kwargs)
#     189   self._function_spec.validate_inputs_with_signature(args, kwargs)
#     191 with self._lock:
# --> 192   concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     193   seen_names = set()
#     194   captured = object_identity.ObjectIdentitySet(
#     195       concrete_function.graph.internal_captures)
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:157, in TracingCompiler._maybe_define_concrete_function(self, args, kwargs)
#     154   args = self.input_signature
#     155   kwargs = {}
# --> 157 return self._maybe_define_function(args, kwargs)
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:360, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     357   # Only get placeholders for arguments, not captures
#     358   args, kwargs = generalized_func_key._placeholder_value()  # pylint: disable=protected-access
# --> 360 concrete_function = self._create_concrete_function(args, kwargs)
#     362 graph_capture_container = concrete_function.graph._capture_func_lib  # pylint: disable=protected-access
#     363 # Maintain the list of all captures
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:284, in TracingCompiler._create_concrete_function(self, args, kwargs)
#     279 missing_arg_names = [
#     280     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#     281 ]
#     282 arg_names = base_arg_names + missing_arg_names
#     283 concrete_function = monomorphic_function.ConcreteFunction(
# --> 284     func_graph_module.func_graph_from_py_func(
#     285         self._name,
#     286         self._python_function,
#     287         args,
#     288         kwargs,
#     289         None,
#     290         autograph=self._autograph,
#     291         autograph_options=self._autograph_options,
#     292         arg_names=arg_names,
#     293         capture_by_value=self._capture_by_value),
#     294     self._function_attributes,
#     295     spec=self.function_spec,
#     296     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     297     # scope. This is not the default behavior since it gets used in some
#     298     # places (like Keras) where the FuncGraph lives longer than the
#     299     # ConcreteFunction.
#     300     shared_func_graph=False)
#     301 return concrete_function
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1283, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1280 else:
#    1281   _, original_func = tf_decorator.unwrap(python_func)
# -> 1283 func_outputs = python_func(*func_args, **func_kwargs)
#    1285 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1286 # TensorArrays and `None`s.
#    1287 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/data/ops/structured_function.py:240, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     234 @eager_function.defun_with_attributes(
#     235     input_signature=structure.get_flat_tensor_specs(
#     236         self._input_structure),
#     237     autograph=False,
#     238     attributes=defun_kwargs)
#     239 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 240   ret = wrapper_helper(*args)
#     241   ret = structure.to_tensor_list(self._output_structure, ret)
#     242   return [ops.convert_to_tensor(t) for t in ret]
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/data/ops/structured_function.py:171, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     169 if not _should_unpack(nested_args):
#     170   nested_args = (nested_args,)
# --> 171 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     172 ret = variable_utils.convert_variables_to_tensors(ret)
#     173 if _should_pack(ret):
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/keras/engine/data_adapter.py:333, in TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices(indices)
#     331 flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#     332 if self._partial_batch_size:
# --> 333     index_remainder = tf.data.Dataset.from_tensors(
#     334         tf.slice(
#     335             indices, [num_in_full_batch], [self._partial_batch_size]
#     336         )
#     337     )
#     338     flat_dataset = flat_dataset.concatenate(index_remainder)
#     340 if shuffle == "batch":
#     341     # 1024 is a magic constant that has not been properly evaluated
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:735, in DatasetV2.from_tensors(tensors, name)
#     698 @staticmethod
#     699 def from_tensors(tensors, name=None):
#     700   """Creates a `Dataset` with a single element, comprising the given tensors.
#     701
#     702   `from_tensors` produces a dataset containing only a single element. To slice
#    (...)
#     733     Dataset: A `Dataset`.
#     734   """
# --> 735   return TensorDataset(tensors, name=name)
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:4827, in TensorDataset.__init__(self, element, name)
#    4825 self._tensors = structure.to_tensor_list(self._structure, element)
#    4826 self._name = name
# -> 4827 variant_tensor = gen_dataset_ops.tensor_dataset(
#    4828     self._tensors,
#    4829     output_shapes=structure.get_flat_tensor_shapes(self._structure),
#    4830     metadata=self._metadata.SerializeToString())
#    4831 super(TensorDataset, self).__init__(variant_tensor)
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/ops/gen_dataset_ops.py:7796, in tensor_dataset(components, output_shapes, metadata, name)
#    7794   metadata = ""
#    7795 metadata = _execute.make_str(metadata, "metadata")
# -> 7796 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    7797       "TensorDataset", components=components, output_shapes=output_shapes,
#    7798                        metadata=metadata, name=name)
#    7799 _result = _outputs[:]
#    7800 if _execute.must_record_gradient():
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/framework/op_def_library.py:795, in _apply_op_helper(op_type_name, name, **keywords)
#     790 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     791                         if arg.is_ref]
#     792 with _MaybeColocateWith(must_colocate_inputs):
#     793   # Add Op to graph
#     794   # pylint: disable=protected-access
# --> 795   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     796                              name=scope, input_types=input_types,
#     797                              attrs=attr_protos, op_def=op_def)
#     799 # `outputs` is returned as a separate return value so that the output
#     800 # tensors can the `op` per se can be decoupled so that the
#     801 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     802 # for more details.
#     803 outputs = op.outputs
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:749, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     747   inp = self.capture(inp)
#     748   captured_inputs.append(inp)
# --> 749 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     750     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     751     compute_device)
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:3807, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3797 with self._mutation_lock():
#    3798   ret = Operation(
#    3799       node_def,
#    3800       self,
#    (...)
#    3805       original_op=self._default_original_op,
#    3806       op_def=op_def)
# -> 3807   self._create_op_helper(ret, compute_device=compute_device)
#    3808 return ret
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:3868, in Graph._create_op_helper(self, op, compute_device)
#    3865 except KeyError:
#    3866   pass
# -> 3868 op._gradient_function = self._gradient_function_map.get(op.type)  # pylint: disable=protected-access
#    3870 # Apply the overriding op type for gradients if one has been specified for
#    3871 # this op type.
#    3872 try:
#
# File /opt/anaconda3/envs/IS/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:2581, in Operation.type(self)
#    2578 @property
#    2579 def type(self):
#    2580   """The type of the op (e.g. `"MatMul"`)."""
# -> 2581   return pywrap_tf_session.TF_OperationOpType(self._c_op)
#
# KeyboardInterrupt:
